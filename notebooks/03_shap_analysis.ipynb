# %% [markdown]
# # 03 — SHAP Analysis
#
# Evaluates on: `data/test/1970-2021_DISASTERS.xlsx - test data` (holdout — NEVER used in training)
#
# Goals:
# - Instantiate shap.TreeExplainer(disaster_predictor) and cache it → `shap_explainer.pkl`
# - Validate SHAP feature importance on test set (top 3 features per prediction)
# - Report model accuracy + F1 on holdout (values shown at GET /admin/model-stats)
# - SHAP TreeExplainer must be saved as .pkl so FastAPI loads it at startup (saves ~200ms per request)
