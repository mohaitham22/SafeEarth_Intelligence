# %% [markdown]
# # 01 — Exploratory Data Analysis
#
# Reads: `data/train/1900_2021_DISASTERS_xlsx_-_train_data.csv`
#
# Goals:
# - Understand feature distributions, missing value patterns, and class imbalance
# - Profile Dis Mag Value coverage by disaster type (earthquake/storm/flood)
# - Identify columns needed for ML feature engineering
# - NEVER use mean for skewed disaster metrics — always median
